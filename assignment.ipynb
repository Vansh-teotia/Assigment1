# %% [markdown]
# # My Jupyter Notebook on IBM Watson

# %% [markdown]
# **Vansh Teotia**

# %% [markdown]
# College Student

# %% [markdown]
# *I am interested in data science because it is one of the fastest emerging fields of the 21st energy with lots of space for growth and it seems like a good application of my analytical skills*

# %% [markdown]
# ### My code takes an input from the user and adds 5 to it

# %%
a=int(input("enter a number:"))
b=a+5
print("New number is:",b)
# Out:
# enter a number:5
# New number is: 10

# %% [markdown]
# ### Bulleted list
#
#
# *   List item1
# *   List item2
# *   List item3
#
# ### Numbered list
#
#
# 1.   List item1
# 2.   List item2
# 3.   List item3
#
#
# ### Image
# ![class_count.png](data:image/png;base64,...)
